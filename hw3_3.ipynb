# %% [markdown]
# # 3-3. Chambolle-Pock
# CT image reconstruction

# %%
''' import '''
import scipy.io as io
import numpy as np
import numpy.linalg as la
import scipy.sparse as sp
import scipy.sparse.linalg as sla
import matplotlib.pyplot as plt

# %%
''' load data '''
data = io.loadmat('./data/hw3_prob3.mat')

A = data['A']               # (30720, 65536)
b = data['b']               # (30720, 1)
x_orig = data['x_orig']     # (256, 256)

M, N = x_orig.shape
K, _ = b.shape

# %%
# ''' plot img '''
# x = x_orig.reshape(-1, 1)

# img = (A.T@b).reshape(M,N)
# err = (A@x - b).reshape(120, N)
# # plt.imshow(err, cmap='gray')
# # plt.imshow(img, cmap='gray')
# plt.imshow(x_orig, cmap='gray')
# plt.show()

# %%
''' hyper param '''
MU = 1
LAMBDA = 0.0002
MAXITERS = 500
CRIT = 5e-4

L = sla.norm(A, ord=2)**2 # sigma*tau*L^2 <= 1, sigma*tau < 1/L^2

# %%
''' function '''
def trunc(z, t):
    return np.sign(z)*np.minimum(np.abs(z), t)

# %%
''' TV (D_h, D_v) '''
Im = sp.eye(M)
Dn = sp.diags([1, -1, 1], offsets=(-(N-1), 0, 1), shape=(N,N))
D_h = sp.kron(Im, Dn)

In = sp.eye(N)
Dm = sp.diags([1, -1, 1], offsets=(-(M-1), 0, 1), shape=(M,M))
D_v = sp.kron(Dm, In)

# %%
''' Chambolle-Pock '''

MAXITERS = 300
CRIT = 1e-7
tau = 1/L
sigma = 1/L
theta = 1 / np.sqrt(1 + 2*MU*tau) # tau는 왜?

fn_cham = []
xn_cham = []

x = np.ones((M*N, 1))
# x = x_orig.reshape(-1,1)
x_prev = x

y1 = np.zeros((K, 1))
y2 = np.zeros((M*N, 1))
y3 = np.zeros((M*N, 1))

for k in range(MAXITERS):

    # f
    fn = (MU/2)*la.norm(A@x - b)**2 + LAMBDA*la.norm(D_h@x, 1) + LAMBDA*la.norm(D_v@x, 1)

    # update
    y1 = ((y1 + sigma*(A@x)) + sigma*MU*b) / (1 + sigma*MU)
    y2 = trunc(y2 - sigma*D_h@x, sigma)
    y3 = trunc(y3 - sigma*D_v@x, sigma)

    x = np.maximum(x - tau*(A.T@y1 + D_h.T@y2 + D_v.T@y3), 0)

    theta = 1 / np.sqrt(1 + 2*MU*tau)
    tau = theta*tau
    sigma = sigma/theta
    
    if (k >= 1):
        x = x + theta*(x - x_prev)
    
    # stop condition
    xcon = la.norm(x - x_prev)/la.norm(x)
    if (k >= 1) and (la.norm(x - x_prev)/la.norm(x) < CRIT):
        break
    
    x_prev = x

    # history
    fn_cham.append(fn)
    xn_cham.append(xcon)
    print(f'i = {k:<4d}, |x-x|/|x| = {xcon:.8f}, σ = {sigma:.5f}, τ = {tau:.5f}, f = {fn:.0f}')
    # print(f'i = {k:<4d}, {sigma}, {tau}, f = {fn:.0f}')

# optimal
x_cham = x
# Out:
# i = 0   , |x-x|/|x| = 0.00519606, σ = 0.00004, τ = 0.00004, f = 16989329057516
# i = 1   , |x-x|/|x| = 0.02120700, σ = 0.00004, τ = 0.00004, f = 16990498891705
# i = 2   , |x-x|/|x| = 0.03281017, σ = 0.00004, τ = 0.00004, f = 16995178318068
# i = 3   , |x-x|/|x| = 0.04565403, σ = 0.00004, τ = 0.00004, f = 17002198133204
# i = 4   , |x-x|/|x| = 0.06034092, σ = 0.00004, τ = 0.00004, f = 17011559238022
# i = 5   , |x-x|/|x| = 0.07772337, σ = 0.00004, τ = 0.00004, f = 17023262892545
# i = 6   , |x-x|/|x| = 0.09907663, σ = 0.00004, τ = 0.00004, f = 17037310715041
# i = 7   , |x-x|/|x| = 0.12640853, σ = 0.00004, τ = 0.00004, f = 17053704680950
# i = 8   , |x-x|/|x| = 0.16302847, σ = 0.00004, τ = 0.00004, f = 17072447121627
# i = 9   , |x-x|/|x| = 0.21453293, σ = 0.00004, τ = 0.00004, f = 17093540722893
# i = 10  , |x-x|/|x| = 0.28980988, σ = 0.00004, τ = 0.00004, f = 17116988523396
# i = 11  , |x-x|/|x| = 0.38821173, σ = 0.00004, τ = 0.00004, f = 17142793912784
# i = 12  , |x-x|/|x| = 0.44580174, σ = 0.00004, τ = 0.00004, f = 17170143856459
# i = 13  , |x-x|/|x| = 0.52186487, σ = 0.00004, τ = 0.00004, f = 17186306926499
# i = 14  , |x-x|/|x| = 0.70365102, σ = 0.00004, τ = 0.00004, f = 17190425017119
# i = 15  , |x-x|/|x| = 0.98038902, σ = 0.00004, τ = 0.00004, f = 17200740149734
# i = 16  , |x-x|/|x| = 1.37321795, σ = 0.00004, τ = 0.00004, f = 17201492247258
# i = 17  , |x-x|/|x| = 1.77922422, σ = 0.00004, τ = 0.00004, f = 17208181712507
# i = 18  , |x-x|/|x| = 1.98709845, σ = 0.00004, τ = 0.00004, f = 17205550525769
# i = 19  , |x-x|/|x| = 2.01075053, σ = 0.00004, τ = 0.00004, f = 17209981809105
# i = 20  , |x-x|/|x| = 2.00003839, σ = 0.00004, τ = 0.00004, f = 17206146702925
# i = 21  , |x-x|/|x| = 2.00003839, σ = 0.00004, τ = 0.00004, f = 17210093330679
# i = 22  , |x-x|/|x| = 2.00003838, σ = 0.00004, τ = 0.00004, f = 17206146854376
# i = 23  , |x-x|/|x| = 2.00003838, σ = 0.00004, τ = 0.00004, f = 17210093179154
# i = 24  , |x-x|/|x| = 2.00003838, σ = 0.00004, τ = 0.00004, f = 17206147005805
# i = 25  , |x-x|/|x| = 2.00003838, σ = 0.00004, τ = 0.00004, f = 17210093027653
# i = 26  , |x-x|/|x| = 2.00003838, σ = 0.00004, τ = 0.00004, f = 17206147157210
# i = 27  , |x-x|/|x| = 2.00003838, σ = 0.00004, τ = 0.00004, f = 17210092876176
# i = 28  , |x-x|/|x| = 2.00003838, σ = 0.00004, τ = 0.00004, f = 17206147308592
# i = 29  , |x-x|/|x| = 2.00003837, σ = 0.00004, τ = 0.00004, f = 17210092724721
# i = 30  , |x-x|/|x| = 2.00003837, σ = 0.00004, τ = 0.00004, f = 17206147459950
# i = 31  , |x-x|/|x| = 2.00003837, σ = 0.00004, τ = 0.00004, f = 17210092573290
# i = 32  , |x-x|/|x| = 2.00003837, σ = 0.00004, τ = 0.00004, f = 17206147611285
# i = 33  , |x-x|/|x| = 2.00003837, σ = 0.00004, τ = 0.00004, f = 17210092421882
# i = 34  , |x-x|/|x| = 2.00003837, σ = 0.00004, τ = 0.00004, f = 17206147762598
# i = 35  , |x-x|/|x| = 2.00003837, σ = 0.00004, τ = 0.00004, f = 17210092270497
# i = 36  , |x-x|/|x| = 2.00003836, σ = 0.00004, τ = 0.00004, f = 17206147913887
# i = 37  , |x-x|/|x| = 2.00003836, σ = 0.00004, τ = 0.00004, f = 17210092119136
# i = 38  , |x-x|/|x| = 2.00003836, σ = 0.00004, τ = 0.00004, f = 17206148065152
# i = 39  , |x-x|/|x| = 2.00003836, σ = 0.00004, τ = 0.00004, f = 17210091967797
# i = 40  , |x-x|/|x| = 2.00003836, σ = 0.00004, τ = 0.00004, f = 17206148216395
# i = 41  , |x-x|/|x| = 2.00003836, σ = 0.00004, τ = 0.00004, f = 17210091816482
# i = 42  , |x-x|/|x| = 2.00003836, σ = 0.00004, τ = 0.00004, f = 17206148367614
# i = 43  , |x-x|/|x| = 2.00003835, σ = 0.00004, τ = 0.00004, f = 17210091665190
# i = 44  , |x-x|/|x| = 2.00003835, σ = 0.00004, τ = 0.00004, f = 17206148518810
# i = 45  , |x-x|/|x| = 2.00003835, σ = 0.00004, τ = 0.00004, f = 17210091513922
# i = 46  , |x-x|/|x| = 2.00003835, σ = 0.00004, τ = 0.00004, f = 17206148669983
# i = 47  , |x-x|/|x| = 2.00003835, σ = 0.00004, τ = 0.00004, f = 17210091362676
# i = 48  , |x-x|/|x| = 2.00003835, σ = 0.00004, τ = 0.00004, f = 17206148821133
# i = 49  , |x-x|/|x| = 2.00003835, σ = 0.00004, τ = 0.00004, f = 17210091211454
# i = 50  , |x-x|/|x| = 2.00003834, σ = 0.00004, τ = 0.00004, f = 17206148972259
# i = 51  , |x-x|/|x| = 2.00003834, σ = 0.00004, τ = 0.00004, f = 17210091060255
# i = 52  , |x-x|/|x| = 2.00003834, σ = 0.00004, τ = 0.00004, f = 17206149123363
# i = 53  , |x-x|/|x| = 2.00003834, σ = 0.00004, τ = 0.00004, f = 17210090909079
# i = 54  , |x-x|/|x| = 2.00003834, σ = 0.00004, τ = 0.00004, f = 17206149274443
# i = 55  , |x-x|/|x| = 2.00003834, σ = 0.00004, τ = 0.00004, f = 17210090757926
# i = 56  , |x-x|/|x| = 2.00003833, σ = 0.00004, τ = 0.00004, f = 17206149425500
# i = 57  , |x-x|/|x| = 2.00003833, σ = 0.00004, τ = 0.00004, f = 17210090606797
# i = 58  , |x-x|/|x| = 2.00003833, σ = 0.00004, τ = 0.00004, f = 17206149576534
# i = 59  , |x-x|/|x| = 2.00003833, σ = 0.00004, τ = 0.00004, f = 17210090455691
# i = 60  , |x-x|/|x| = 2.00003833, σ = 0.00004, τ = 0.00004, f = 17206149727545
# i = 61  , |x-x|/|x| = 2.00003833, σ = 0.00004, τ = 0.00004, f = 17210090304608
# i = 62  , |x-x|/|x| = 2.00003833, σ = 0.00004, τ = 0.00004, f = 17206149878532
# i = 63  , |x-x|/|x| = 2.00003832, σ = 0.00004, τ = 0.00004, f = 17210090153547
# i = 64  , |x-x|/|x| = 2.00003832, σ = 0.00004, τ = 0.00004, f = 17206150029496
# i = 65  , |x-x|/|x| = 2.00003832, σ = 0.00004, τ = 0.00004, f = 17210090002511
# i = 66  , |x-x|/|x| = 2.00003832, σ = 0.00004, τ = 0.00004, f = 17206150180438
# i = 67  , |x-x|/|x| = 2.00003832, σ = 0.00004, τ = 0.00004, f = 17210089851497
# i = 68  , |x-x|/|x| = 2.00003832, σ = 0.00004, τ = 0.00004, f = 17206150331356
# i = 69  , |x-x|/|x| = 2.00003832, σ = 0.00004, τ = 0.00004, f = 17210089700506
# i = 70  , |x-x|/|x| = 2.00003831, σ = 0.00004, τ = 0.00004, f = 17206150482251
# i = 71  , |x-x|/|x| = 2.00003831, σ = 0.00004, τ = 0.00004, f = 17210089549539
# i = 72  , |x-x|/|x| = 2.00003831, σ = 0.00004, τ = 0.00004, f = 17206150633123
# i = 73  , |x-x|/|x| = 2.00003831, σ = 0.00004, τ = 0.00004, f = 17210089398595
# i = 74  , |x-x|/|x| = 2.00003831, σ = 0.00004, τ = 0.00004, f = 17206150783972
# i = 75  , |x-x|/|x| = 2.00003831, σ = 0.00004, τ = 0.00004, f = 17210089247674
# i = 76  , |x-x|/|x| = 2.00003831, σ = 0.00004, τ = 0.00004, f = 17206150934797
# i = 77  , |x-x|/|x| = 2.00003830, σ = 0.00004, τ = 0.00004, f = 17210089096776
# i = 78  , |x-x|/|x| = 2.00003830, σ = 0.00004, τ = 0.00004, f = 17206151085600
# i = 79  , |x-x|/|x| = 2.00003830, σ = 0.00004, τ = 0.00004, f = 17210088945901
# i = 80  , |x-x|/|x| = 2.00003830, σ = 0.00004, τ = 0.00004, f = 17206151236380
# i = 81  , |x-x|/|x| = 2.00003830, σ = 0.00004, τ = 0.00004, f = 17210088795049
# i = 82  , |x-x|/|x| = 2.00003830, σ = 0.00004, τ = 0.00004, f = 17206151387136
# i = 83  , |x-x|/|x| = 2.00003830, σ = 0.00004, τ = 0.00004, f = 17210088644221
# i = 84  , |x-x|/|x| = 2.00003829, σ = 0.00004, τ = 0.00004, f = 17206151537869
# i = 85  , |x-x|/|x| = 2.00003829, σ = 0.00004, τ = 0.00004, f = 17210088493415
# i = 86  , |x-x|/|x| = 2.00003829, σ = 0.00004, τ = 0.00004, f = 17206151688580
# i = 87  , |x-x|/|x| = 2.00003829, σ = 0.00004, τ = 0.00004, f = 17210088342632
# i = 88  , |x-x|/|x| = 2.00003829, σ = 0.00004, τ = 0.00004, f = 17206151839267
# i = 89  , |x-x|/|x| = 2.00003829, σ = 0.00004, τ = 0.00004, f = 17210088191873
# i = 90  , |x-x|/|x| = 2.00003828, σ = 0.00004, τ = 0.00004, f = 17206151989931
# i = 91  , |x-x|/|x| = 2.00003828, σ = 0.00004, τ = 0.00004, f = 17210088041137
# i = 92  , |x-x|/|x| = 2.00003828, σ = 0.00004, τ = 0.00004, f = 17206152140572
# i = 93  , |x-x|/|x| = 2.00003828, σ = 0.00004, τ = 0.00004, f = 17210087890424
# i = 94  , |x-x|/|x| = 2.00003828, σ = 0.00004, τ = 0.00004, f = 17206152291190
# i = 95  , |x-x|/|x| = 2.00003828, σ = 0.00004, τ = 0.00004, f = 17210087739734
# i = 96  , |x-x|/|x| = 2.00003828, σ = 0.00004, τ = 0.00004, f = 17206152441785
# i = 97  , |x-x|/|x| = 2.00003827, σ = 0.00004, τ = 0.00004, f = 17210087589067
# i = 98  , |x-x|/|x| = 2.00003827, σ = 0.00004, τ = 0.00004, f = 17206152592357
# i = 99  , |x-x|/|x| = 2.00003827, σ = 0.00004, τ = 0.00004, f = 17210087438423
# i = 100 , |x-x|/|x| = 2.00003827, σ = 0.00004, τ = 0.00004, f = 17206152742905
# i = 101 , |x-x|/|x| = 2.00003827, σ = 0.00004, τ = 0.00004, f = 17210087287802
# i = 102 , |x-x|/|x| = 2.00003827, σ = 0.00004, τ = 0.00004, f = 17206152893431
# i = 103 , |x-x|/|x| = 2.00003827, σ = 0.00004, τ = 0.00004, f = 17210087137204
# i = 104 , |x-x|/|x| = 2.00003826, σ = 0.00004, τ = 0.00004, f = 17206153043934
# i = 105 , |x-x|/|x| = 2.00003826, σ = 0.00004, τ = 0.00004, f = 17210086986629
# i = 106 , |x-x|/|x| = 2.00003826, σ = 0.00004, τ = 0.00004, f = 17206153194413
# i = 107 , |x-x|/|x| = 2.00003826, σ = 0.00004, τ = 0.00004, f = 17210086836078
# i = 108 , |x-x|/|x| = 2.00003826, σ = 0.00004, τ = 0.00004, f = 17206153344870
# i = 109 , |x-x|/|x| = 2.00003826, σ = 0.00004, τ = 0.00004, f = 17210086685549
# i = 110 , |x-x|/|x| = 2.00003826, σ = 0.00004, τ = 0.00004, f = 17206153495304
# i = 111 , |x-x|/|x| = 2.00003825, σ = 0.00004, τ = 0.00004, f = 17210086535043
# i = 112 , |x-x|/|x| = 2.00003825, σ = 0.00004, τ = 0.00004, f = 17206153645714
# i = 113 , |x-x|/|x| = 2.00003825, σ = 0.00004, τ = 0.00004, f = 17210086384561
# i = 114 , |x-x|/|x| = 2.00003825, σ = 0.00004, τ = 0.00004, f = 17206153796102
# i = 115 , |x-x|/|x| = 2.00003825, σ = 0.00004, τ = 0.00004, f = 17210086234101
# i = 116 , |x-x|/|x| = 2.00003825, σ = 0.00004, τ = 0.00004, f = 17206153946467
# i = 117 , |x-x|/|x| = 2.00003825, σ = 0.00004, τ = 0.00004, f = 17210086083664
# i = 118 , |x-x|/|x| = 2.00003824, σ = 0.00004, τ = 0.00004, f = 17206154096808
# i = 119 , |x-x|/|x| = 2.00003824, σ = 0.00004, τ = 0.00004, f = 17210085933251
# i = 120 , |x-x|/|x| = 2.00003824, σ = 0.00004, τ = 0.00004, f = 17206154247127
# i = 121 , |x-x|/|x| = 2.00003824, σ = 0.00004, τ = 0.00004, f = 17210085782860
# i = 122 , |x-x|/|x| = 2.00003824, σ = 0.00004, τ = 0.00004, f = 17206154397423
# i = 123 , |x-x|/|x| = 2.00003824, σ = 0.00004, τ = 0.00004, f = 17210085632493
# i = 124 , |x-x|/|x| = 2.00003824, σ = 0.00004, τ = 0.00004, f = 17206154547695
# i = 125 , |x-x|/|x| = 2.00003823, σ = 0.00004, τ = 0.00004, f = 17210085482148
# i = 126 , |x-x|/|x| = 2.00003823, σ = 0.00004, τ = 0.00004, f = 17206154697945
# i = 127 , |x-x|/|x| = 2.00003823, σ = 0.00004, τ = 0.00004, f = 17210085331827
# i = 128 , |x-x|/|x| = 2.00003823, σ = 0.00004, τ = 0.00004, f = 17206154848172
# i = 129 , |x-x|/|x| = 2.00003823, σ = 0.00004, τ = 0.00004, f = 17210085181528
# i = 130 , |x-x|/|x| = 2.00003823, σ = 0.00004, τ = 0.00004, f = 17206154998375
# i = 131 , |x-x|/|x| = 2.00003822, σ = 0.00004, τ = 0.00004, f = 17210085031253
# i = 132 , |x-x|/|x| = 2.00003822, σ = 0.00004, τ = 0.00004, f = 17206155148556
# i = 133 , |x-x|/|x| = 2.00003822, σ = 0.00004, τ = 0.00004, f = 17210084881000
# i = 134 , |x-x|/|x| = 2.00003822, σ = 0.00004, τ = 0.00004, f = 17206155298714
# i = 135 , |x-x|/|x| = 2.00003822, σ = 0.00004, τ = 0.00004, f = 17210084730770
# i = 136 , |x-x|/|x| = 2.00003822, σ = 0.00004, τ = 0.00004, f = 17206155448849
# i = 137 , |x-x|/|x| = 2.00003822, σ = 0.00004, τ = 0.00004, f = 17210084580564
# i = 138 , |x-x|/|x| = 2.00003821, σ = 0.00004, τ = 0.00004, f = 17206155598961
# i = 139 , |x-x|/|x| = 2.00003821, σ = 0.00004, τ = 0.00004, f = 17210084430380
# i = 140 , |x-x|/|x| = 2.00003821, σ = 0.00004, τ = 0.00004, f = 17206155749050
# i = 141 , |x-x|/|x| = 2.00003821, σ = 0.00004, τ = 0.00004, f = 17210084280219
# i = 142 , |x-x|/|x| = 2.00003821, σ = 0.00004, τ = 0.00004, f = 17206155899116
# i = 143 , |x-x|/|x| = 2.00003821, σ = 0.00004, τ = 0.00004, f = 17210084130081
# i = 144 , |x-x|/|x| = 2.00003821, σ = 0.00004, τ = 0.00004, f = 17206156049159
# i = 145 , |x-x|/|x| = 2.00003820, σ = 0.00004, τ = 0.00004, f = 17210083979967
# i = 146 , |x-x|/|x| = 2.00003820, σ = 0.00004, τ = 0.00004, f = 17206156199179
# i = 147 , |x-x|/|x| = 2.00003820, σ = 0.00004, τ = 0.00004, f = 17210083829875
# i = 148 , |x-x|/|x| = 2.00003820, σ = 0.00004, τ = 0.00004, f = 17206156349176
# i = 149 , |x-x|/|x| = 2.00003820, σ = 0.00004, τ = 0.00004, f = 17210083679806
# i = 150 , |x-x|/|x| = 2.00003820, σ = 0.00004, τ = 0.00004, f = 17206156499151
# i = 151 , |x-x|/|x| = 2.00003820, σ = 0.00004, τ = 0.00004, f = 17210083529760
# i = 152 , |x-x|/|x| = 2.00003819, σ = 0.00004, τ = 0.00004, f = 17206156649102
# i = 153 , |x-x|/|x| = 2.00003819, σ = 0.00004, τ = 0.00004, f = 17210083379737
# i = 154 , |x-x|/|x| = 2.00003819, σ = 0.00004, τ = 0.00004, f = 17206156799031
# i = 155 , |x-x|/|x| = 2.00003819, σ = 0.00004, τ = 0.00004, f = 17210083229736
# i = 156 , |x-x|/|x| = 2.00003819, σ = 0.00004, τ = 0.00004, f = 17206156948936
# i = 157 , |x-x|/|x| = 2.00003819, σ = 0.00004, τ = 0.00004, f = 17210083079759
# i = 158 , |x-x|/|x| = 2.00003819, σ = 0.00004, τ = 0.00004, f = 17206157098819
# i = 159 , |x-x|/|x| = 2.00003818, σ = 0.00004, τ = 0.00004, f = 17210082929805
# i = 160 , |x-x|/|x| = 2.00003818, σ = 0.00004, τ = 0.00004, f = 17206157248679
# i = 161 , |x-x|/|x| = 2.00003818, σ = 0.00004, τ = 0.00004, f = 17210082779873
# i = 162 , |x-x|/|x| = 2.00003818, σ = 0.00004, τ = 0.00004, f = 17206157398516
# i = 163 , |x-x|/|x| = 2.00003818, σ = 0.00004, τ = 0.00004, f = 17210082629965
# i = 164 , |x-x|/|x| = 2.00003818, σ = 0.00004, τ = 0.00004, f = 17206157548330
# i = 165 , |x-x|/|x| = 2.00003818, σ = 0.00004, τ = 0.00004, f = 17210082480079
# i = 166 , |x-x|/|x| = 2.00003817, σ = 0.00004, τ = 0.00004, f = 17206157698121
# i = 167 , |x-x|/|x| = 2.00003817, σ = 0.00004, τ = 0.00004, f = 17210082330216
# i = 168 , |x-x|/|x| = 2.00003817, σ = 0.00004, τ = 0.00004, f = 17206157847889
# i = 169 , |x-x|/|x| = 2.00003817, σ = 0.00004, τ = 0.00004, f = 17210082180376
# i = 170 , |x-x|/|x| = 2.00003817, σ = 0.00004, τ = 0.00004, f = 17206157997635
# i = 171 , |x-x|/|x| = 2.00003817, σ = 0.00004, τ = 0.00004, f = 17210082030559
# i = 172 , |x-x|/|x| = 2.00003817, σ = 0.00004, τ = 0.00004, f = 17206158147358
# i = 173 , |x-x|/|x| = 2.00003816, σ = 0.00004, τ = 0.00004, f = 17210081880765
# i = 174 , |x-x|/|x| = 2.00003816, σ = 0.00004, τ = 0.00004, f = 17206158297057
# i = 175 , |x-x|/|x| = 2.00003816, σ = 0.00004, τ = 0.00004, f = 17210081730994
# i = 176 , |x-x|/|x| = 2.00003816, σ = 0.00004, τ = 0.00004, f = 17206158446734
# i = 177 , |x-x|/|x| = 2.00003816, σ = 0.00004, τ = 0.00004, f = 17210081581246
# i = 178 , |x-x|/|x| = 2.00003816, σ = 0.00004, τ = 0.00004, f = 17206158596388
# i = 179 , |x-x|/|x| = 2.00003815, σ = 0.00004, τ = 0.00004, f = 17210081431520
# i = 180 , |x-x|/|x| = 2.00003815, σ = 0.00004, τ = 0.00004, f = 17206158746020
# i = 181 , |x-x|/|x| = 2.00003815, σ = 0.00004, τ = 0.00004, f = 17210081281817
# i = 182 , |x-x|/|x| = 2.00003815, σ = 0.00004, τ = 0.00004, f = 17206158895628
# i = 183 , |x-x|/|x| = 2.00003815, σ = 0.00004, τ = 0.00004, f = 17210081132137
# i = 184 , |x-x|/|x| = 2.00003815, σ = 0.00004, τ = 0.00004, f = 17206159045214
# i = 185 , |x-x|/|x| = 2.00003815, σ = 0.00004, τ = 0.00004, f = 17210080982481
# i = 186 , |x-x|/|x| = 2.00003814, σ = 0.00004, τ = 0.00004, f = 17206159194777
# i = 187 , |x-x|/|x| = 2.00003814, σ = 0.00004, τ = 0.00004, f = 17210080832846
# i = 188 , |x-x|/|x| = 2.00003814, σ = 0.00004, τ = 0.00004, f = 17206159344316
# i = 189 , |x-x|/|x| = 2.00003814, σ = 0.00004, τ = 0.00004, f = 17210080683235
# i = 190 , |x-x|/|x| = 2.00003814, σ = 0.00004, τ = 0.00004, f = 17206159493834
# i = 191 , |x-x|/|x| = 2.00003814, σ = 0.00004, τ = 0.00004, f = 17210080533647
# i = 192 , |x-x|/|x| = 2.00003814, σ = 0.00004, τ = 0.00004, f = 17206159643328
# i = 193 , |x-x|/|x| = 2.00003813, σ = 0.00004, τ = 0.00004, f = 17210080384081
# i = 194 , |x-x|/|x| = 2.00003813, σ = 0.00004, τ = 0.00004, f = 17206159792800
# i = 195 , |x-x|/|x| = 2.00003813, σ = 0.00004, τ = 0.00004, f = 17210080234538
# i = 196 , |x-x|/|x| = 2.00003813, σ = 0.00004, τ = 0.00004, f = 17206159942248
# i = 197 , |x-x|/|x| = 2.00003813, σ = 0.00004, τ = 0.00004, f = 17210080085018
# i = 198 , |x-x|/|x| = 2.00003813, σ = 0.00004, τ = 0.00004, f = 17206160091674
# i = 199 , |x-x|/|x| = 2.00003813, σ = 0.00004, τ = 0.00004, f = 17210079935521
# i = 200 , |x-x|/|x| = 2.00003812, σ = 0.00004, τ = 0.00004, f = 17206160241078
# i = 201 , |x-x|/|x| = 2.00003812, σ = 0.00004, τ = 0.00004, f = 17210079786046
# i = 202 , |x-x|/|x| = 2.00003812, σ = 0.00004, τ = 0.00004, f = 17206160390458
# i = 203 , |x-x|/|x| = 2.00003812, σ = 0.00004, τ = 0.00004, f = 17210079636594
# i = 204 , |x-x|/|x| = 2.00003812, σ = 0.00004, τ = 0.00004, f = 17206160539816
# i = 205 , |x-x|/|x| = 2.00003812, σ = 0.00004, τ = 0.00004, f = 17210079487166
# i = 206 , |x-x|/|x| = 2.00003812, σ = 0.00004, τ = 0.00004, f = 17206160689151
# i = 207 , |x-x|/|x| = 2.00003811, σ = 0.00004, τ = 0.00004, f = 17210079337760
# i = 208 , |x-x|/|x| = 2.00003811, σ = 0.00004, τ = 0.00004, f = 17206160838463
# i = 209 , |x-x|/|x| = 2.00003811, σ = 0.00004, τ = 0.00004, f = 17210079188376
# i = 210 , |x-x|/|x| = 2.00003811, σ = 0.00004, τ = 0.00004, f = 17206160987752
# i = 211 , |x-x|/|x| = 2.00003811, σ = 0.00004, τ = 0.00004, f = 17210079039016
# i = 212 , |x-x|/|x| = 2.00003811, σ = 0.00004, τ = 0.00004, f = 17206161137019
# i = 213 , |x-x|/|x| = 2.00003811, σ = 0.00004, τ = 0.00004, f = 17210078889678
# i = 214 , |x-x|/|x| = 2.00003810, σ = 0.00004, τ = 0.00004, f = 17206161286262
# i = 215 , |x-x|/|x| = 2.00003810, σ = 0.00004, τ = 0.00004, f = 17210078740363
# i = 216 , |x-x|/|x| = 2.00003810, σ = 0.00004, τ = 0.00004, f = 17206161435484
# i = 217 , |x-x|/|x| = 2.00003810, σ = 0.00004, τ = 0.00004, f = 17210078591071
# i = 218 , |x-x|/|x| = 2.00003810, σ = 0.00004, τ = 0.00004, f = 17206161584682
# i = 219 , |x-x|/|x| = 2.00003810, σ = 0.00004, τ = 0.00004, f = 17210078441801
# i = 220 , |x-x|/|x| = 2.00003810, σ = 0.00004, τ = 0.00004, f = 17206161733858
# i = 221 , |x-x|/|x| = 2.00003809, σ = 0.00004, τ = 0.00004, f = 17210078292554
# i = 222 , |x-x|/|x| = 2.00003809, σ = 0.00004, τ = 0.00004, f = 17206161883010
# i = 223 , |x-x|/|x| = 2.00003809, σ = 0.00004, τ = 0.00004, f = 17210078143330
# i = 224 , |x-x|/|x| = 2.00003809, σ = 0.00004, τ = 0.00004, f = 17206162032141
# i = 225 , |x-x|/|x| = 2.00003809, σ = 0.00004, τ = 0.00004, f = 17210077994129
# i = 226 , |x-x|/|x| = 2.00003809, σ = 0.00004, τ = 0.00004, f = 17206162181248
# i = 227 , |x-x|/|x| = 2.00003809, σ = 0.00004, τ = 0.00004, f = 17210077844951
# i = 228 , |x-x|/|x| = 2.00003808, σ = 0.00004, τ = 0.00004, f = 17206162330333
# i = 229 , |x-x|/|x| = 2.00003808, σ = 0.00004, τ = 0.00004, f = 17210077695795
# i = 230 , |x-x|/|x| = 2.00003808, σ = 0.00004, τ = 0.00004, f = 17206162479395
# i = 231 , |x-x|/|x| = 2.00003808, σ = 0.00004, τ = 0.00004, f = 17210077546662
# i = 232 , |x-x|/|x| = 2.00003808, σ = 0.00004, τ = 0.00004, f = 17206162628434
# i = 233 , |x-x|/|x| = 2.00003808, σ = 0.00004, τ = 0.00004, f = 17210077397551
# i = 234 , |x-x|/|x| = 2.00003808, σ = 0.00004, τ = 0.00004, f = 17206162777451
# i = 235 , |x-x|/|x| = 2.00003807, σ = 0.00004, τ = 0.00004, f = 17210077248464
# i = 236 , |x-x|/|x| = 2.00003807, σ = 0.00004, τ = 0.00004, f = 17206162926445
# i = 237 , |x-x|/|x| = 2.00003807, σ = 0.00004, τ = 0.00004, f = 17210077099399
# i = 238 , |x-x|/|x| = 2.00003807, σ = 0.00004, τ = 0.00004, f = 17206163075416
# i = 239 , |x-x|/|x| = 2.00003807, σ = 0.00004, τ = 0.00004, f = 17210076950356
# i = 240 , |x-x|/|x| = 2.00003807, σ = 0.00004, τ = 0.00004, f = 17206163224365
# i = 241 , |x-x|/|x| = 2.00003806, σ = 0.00004, τ = 0.00004, f = 17210076801337
# i = 242 , |x-x|/|x| = 2.00003806, σ = 0.00004, τ = 0.00004, f = 17206163373291
# i = 243 , |x-x|/|x| = 2.00003806, σ = 0.00004, τ = 0.00004, f = 17210076652340
# i = 244 , |x-x|/|x| = 2.00003806, σ = 0.00004, τ = 0.00004, f = 17206163522194
# i = 245 , |x-x|/|x| = 2.00003806, σ = 0.00004, τ = 0.00004, f = 17210076503366
# i = 246 , |x-x|/|x| = 2.00003806, σ = 0.00004, τ = 0.00004, f = 17206163671075
# i = 247 , |x-x|/|x| = 2.00003806, σ = 0.00004, τ = 0.00004, f = 17210076354414
# i = 248 , |x-x|/|x| = 2.00003805, σ = 0.00004, τ = 0.00004, f = 17206163819933
# i = 249 , |x-x|/|x| = 2.00003805, σ = 0.00004, τ = 0.00004, f = 17210076205486
# i = 250 , |x-x|/|x| = 2.00003805, σ = 0.00004, τ = 0.00004, f = 17206163968768
# i = 251 , |x-x|/|x| = 2.00003805, σ = 0.00004, τ = 0.00004, f = 17210076056579
# i = 252 , |x-x|/|x| = 2.00003805, σ = 0.00004, τ = 0.00004, f = 17206164117581
# i = 253 , |x-x|/|x| = 2.00003805, σ = 0.00004, τ = 0.00004, f = 17210075907696
# i = 254 , |x-x|/|x| = 2.00003805, σ = 0.00004, τ = 0.00004, f = 17206164266371
# i = 255 , |x-x|/|x| = 2.00003804, σ = 0.00004, τ = 0.00004, f = 17210075758835
# i = 256 , |x-x|/|x| = 2.00003804, σ = 0.00004, τ = 0.00004, f = 17206164415138
# i = 257 , |x-x|/|x| = 2.00003804, σ = 0.00004, τ = 0.00004, f = 17210075609997
# i = 258 , |x-x|/|x| = 2.00003804, σ = 0.00004, τ = 0.00004, f = 17206164563883
# i = 259 , |x-x|/|x| = 2.00003804, σ = 0.00004, τ = 0.00004, f = 17210075461181
# i = 260 , |x-x|/|x| = 2.00003804, σ = 0.00004, τ = 0.00004, f = 17206164712605
# i = 261 , |x-x|/|x| = 2.00003804, σ = 0.00004, τ = 0.00004, f = 17210075312389
# i = 262 , |x-x|/|x| = 2.00003803, σ = 0.00004, τ = 0.00004, f = 17206164861304
# i = 263 , |x-x|/|x| = 2.00003803, σ = 0.00004, τ = 0.00004, f = 17210075163618
# i = 264 , |x-x|/|x| = 2.00003803, σ = 0.00004, τ = 0.00004, f = 17206165009981
# i = 265 , |x-x|/|x| = 2.00003803, σ = 0.00004, τ = 0.00004, f = 17210075014871
# i = 266 , |x-x|/|x| = 2.00003803, σ = 0.00004, τ = 0.00004, f = 17206165158635
# i = 267 , |x-x|/|x| = 2.00003803, σ = 0.00004, τ = 0.00004, f = 17210074866146
# i = 268 , |x-x|/|x| = 2.00003803, σ = 0.00004, τ = 0.00004, f = 17206165307267
# i = 269 , |x-x|/|x| = 2.00003802, σ = 0.00004, τ = 0.00004, f = 17210074717443
# i = 270 , |x-x|/|x| = 2.00003802, σ = 0.00004, τ = 0.00004, f = 17206165455876
# i = 271 , |x-x|/|x| = 2.00003802, σ = 0.00004, τ = 0.00004, f = 17210074568764
# i = 272 , |x-x|/|x| = 2.00003802, σ = 0.00004, τ = 0.00004, f = 17206165604462
# i = 273 , |x-x|/|x| = 2.00003802, σ = 0.00004, τ = 0.00004, f = 17210074420107
# i = 274 , |x-x|/|x| = 2.00003802, σ = 0.00004, τ = 0.00004, f = 17206165753026
# i = 275 , |x-x|/|x| = 2.00003802, σ = 0.00004, τ = 0.00004, f = 17210074271472
# i = 276 , |x-x|/|x| = 2.00003801, σ = 0.00004, τ = 0.00004, f = 17206165901568
# i = 277 , |x-x|/|x| = 2.00003801, σ = 0.00004, τ = 0.00004, f = 17210074122860
# i = 278 , |x-x|/|x| = 2.00003801, σ = 0.00004, τ = 0.00004, f = 17206166050086
# i = 279 , |x-x|/|x| = 2.00003801, σ = 0.00004, τ = 0.00004, f = 17210073974271
# i = 280 , |x-x|/|x| = 2.00003801, σ = 0.00004, τ = 0.00004, f = 17206166198582
# i = 281 , |x-x|/|x| = 2.00003801, σ = 0.00004, τ = 0.00004, f = 17210073825704
# i = 282 , |x-x|/|x| = 2.00003801, σ = 0.00004, τ = 0.00004, f = 17206166347056
# i = 283 , |x-x|/|x| = 2.00003800, σ = 0.00004, τ = 0.00004, f = 17210073677160
# i = 284 , |x-x|/|x| = 2.00003800, σ = 0.00004, τ = 0.00004, f = 17206166495507
# i = 285 , |x-x|/|x| = 2.00003800, σ = 0.00004, τ = 0.00004, f = 17210073528638
# i = 286 , |x-x|/|x| = 2.00003800, σ = 0.00004, τ = 0.00004, f = 17206166643935
# i = 287 , |x-x|/|x| = 2.00003800, σ = 0.00004, τ = 0.00004, f = 17210073380139
# i = 288 , |x-x|/|x| = 2.00003800, σ = 0.00004, τ = 0.00004, f = 17206166792341
# i = 289 , |x-x|/|x| = 2.00003800, σ = 0.00004, τ = 0.00004, f = 17210073231663
# i = 290 , |x-x|/|x| = 2.00003799, σ = 0.00004, τ = 0.00004, f = 17206166940724
# i = 291 , |x-x|/|x| = 2.00003799, σ = 0.00004, τ = 0.00004, f = 17210073083209
# i = 292 , |x-x|/|x| = 2.00003799, σ = 0.00004, τ = 0.00004, f = 17206167089085
# i = 293 , |x-x|/|x| = 2.00003799, σ = 0.00004, τ = 0.00004, f = 17210072934778
# i = 294 , |x-x|/|x| = 2.00003799, σ = 0.00004, τ = 0.00004, f = 17206167237423
# i = 295 , |x-x|/|x| = 2.00003799, σ = 0.00004, τ = 0.00004, f = 17210072786369
# i = 296 , |x-x|/|x| = 2.00003799, σ = 0.00004, τ = 0.00004, f = 17206167385739
# i = 297 , |x-x|/|x| = 2.00003798, σ = 0.00004, τ = 0.00004, f = 17210072637983
# i = 298 , |x-x|/|x| = 2.00003798, σ = 0.00004, τ = 0.00004, f = 17206167534032
# i = 299 , |x-x|/|x| = 2.00003798, σ = 0.00004, τ = 0.00004, f = 17210072489619

# %%
plt.semilogy(fn_cham)
plt.show()

plt.semilogy(xn_cham)
plt.show()

# %%
plt.imshow(x_cham.reshape(M,N), cmap='gray')
plt.title('Chambolle-Pock')
plt.axis('off')
# err = (A@x_cham-b).reshape(120, N)
# plt.imshow(err, cmap='gray')
plt.show()
